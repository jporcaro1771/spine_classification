# %%
from psycopg2 import connect
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
from sqlalchemy import create_engine
import pandas as pd
import pandas.io.sql as pd_sql
import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('cleaned_df','rb') as read_file:
    df = pickle.load(read_file)

# %%
df.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope Class_att
# ...

# %%
df.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'Direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope', 'Class_att'],
#       dtype='object')

# %%
params = {
    'host': '18.223.164.7',  # You will need to put the PUBLIC IP address of your AWS instance here
    'user': 'ubuntu',    # your username on AWS is 'ubuntu'
    'dbname': 'spine',    # DB that we are connecting to
    'port': 5432             # port we opened on AWS
}

# We will talk about this magic Python trick!
connection = pg.connect(**connection_args)
cursor = connection.cursor()

# %%
# Connect and create database, disconnect, and reconnect to the right database
connection = connect(**params)
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
connection.cursor().execute('CREATE DATABASE spinedata;')
connection.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-40-ecf36d265390> in <module>()
#       2 connection = connect(**params)
#       3 connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
# ----> 4 connection.cursor().execute('CREATE DATABASE spinedata;')
#       5 connection.close()
#
# ProgrammingError: database "spinedata" already exists

# %%
connection_string = f'postgres://ubuntu:{params["host"]}@{params["host"]}:{params["port"]}/spinedata'
engine = create_engine(connection_string)

# %%
df.to_sql('spine', engine, index=False)

# %%
query = """
    SELECT * FROM spine;
"""

# %%
pd.read_sql(query, engine)
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# 5           40.250200    13.921907              25.124950     26.328293
# 6           53.432928    15.864336              37.165934     37.568592
# 7           45.366754    10.755611              29.038349     34.611142
# 8           43.790190    13.533753              42.690814     30.256437
# 9           36.686353     5.010884              41.948751     31.675469
# 10          49.706610    13.040974              31.334500     36.665635
# 11          31.232387    17.715819              15.500000     13.516568
# ...
